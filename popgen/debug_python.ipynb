 1, 2, 4, 1, 2, 4, 4, 1, 2, 4, 2, 4, 1, 3, 2, 4, 2, 1, 1, 4, 4, 1, 1, 4, 1, 3, 1, 2, 4, 3, 3, 1, 4, 3, 3, 1, 3, 3, 1, 4, 1, 1, 1, 3, 4, 4, 3, 2, 1, 3, 3, 1, 2, 2, 1, 2, 4, 4, 2, 4, 3, 2, 3, 2, 4, 2, 3, 3, 2, 2, 2, 4, 4, 2, 2, 3, 3, 2, 4, 3, 3, 2, 4, 3, 3, 4, 4, 4, 1, 4, 4, 3, 2, 4, 3, 1, 4, 1, 1, 1, 4, 2, 4, 3, 3, 1, 3, 2, 2, 3, 1, 3, 2, 3, 4, 3, 3, 3, 4, 2, 4, 2, 3, 2, 3, 3, 4, 1, 4, 2, 1, 4, 4, 3, 2, 1, 3, 2, 1, 2, 4, 3, 3, 3, 3, 2, 2, 1, 3, 1, 4, 3, 3, 4, 1, 1, 3, 2, 2, 2, 4, 2, 2, 2, 3, 4, 1, 4, 2, 5, 5, 5]
seq_wt_nucl = ''
seq_wt_dig_codons = []
seq_wt_nucl_codons = []
for i in range(len(seq_wt_dig)):
    seq_wt_nucl += dig2nucl[seq_wt_dig[i]]
    if i%3 == 0:
        seq_wt_dig_codons.append(seq_wt_dig[i:i+3])

StopCodons = ['TAA','TAG','TGA']
StopCodons_dig = [[4,1,1],[4,1,3],[4,3,1]]
nucl_sites = np.array([28, 31, 58, 72, 83, 83, 103, 106, 132, 132, 136, 146, 151, 156, 156, 158, 158, 169, 172, 199, 202, 206, 206, 210, 251, 251, 268, 274, 277, 293, 333, 334, 340, 364, 404, 409, 416, 416, 424, 442, 446, 446, 455, 456, 460, 466, 475, 491, 523, 529, 535, 580]) - 1
sites = [x // 3 for x in nucl_sites]


c = 0
for site in sites:
    d = 100
    for SC in StopCodons_dig:
        diff = sum(x != y for x, y in zip(seq_wt_dig_codons[site], SC))
        if diff<d:
            d = diff
    if d == 1: c += 1
print(f"{c} out of {len(sites)} sites are at distance 1")

sites_at_dist1 = []
for (site,cod) in enumerate(seq_wt_dig_codons):
    d = 100
    for SC in StopCodons_dig:
        diff = sum(x != y for x, y in zip(cod, SC))
        if diff<d:
            d = diff
    if d == 1: sites_at_dist1.append(site)
    
missing = list(set(sites_at_dist1)-set(sites))
print(f"There are {len(missing)} sites that are at distance 1 from a stop codon and do not appear in the list given by Leo")
# Out:
# 27 out of 56 sites are at distance 1
# There are 26 sites that are at distance 1 from a stop codon and do not appear in the list given by Leo

# %%
nucl2dig = dict()
nucl2dig['A'] = 1
nucl2dig['C'] = 2
nucl2dig['G'] = 3
nucl2dig['T'] = 4
nucl2dig['-'] = 5
dig2nucl = dict()
dig2nucl[1] = 'A'
dig2nucl[2] = 'C'
dig2nucl[3] = 'G'
dig2nucl[4] = 'T'
dig2nucl[5] = '-'
1, 1, 3, 3, 2, 1, 1, 4, 1, 3, 2, 2, 1, 3, 4, 1, 2, 4, 4, 4, 3, 1, 1, 4, 1, 1, 1, 4, 4, 4, 4, 4, 1, 4, 4, 4, 3, 3, 4, 4, 2, 2, 3, 2, 3, 2, 4, 1, 4, 2, 4, 3, 1, 1, 1, 4, 3, 1, 1, 1, 4, 4, 1, 3, 1, 3, 4, 2, 4, 4, 3, 3, 1, 4, 3, 3, 4, 3, 1, 1, 4, 2, 1, 1, 3, 4, 2, 1, 2, 4, 3, 3, 4, 1, 1, 4, 4, 4, 1, 2, 4, 1, 2, 3, 4, 4, 2, 1, 3, 4, 1, 4, 4, 3, 2, 2, 3, 3, 2, 3, 3, 3, 1, 4, 3, 3, 1, 1, 2, 1, 4, 4, 3, 2, 3, 3, 1, 4, 2, 3, 2, 4, 2, 1, 3, 3, 4, 3, 2, 4, 3, 3, 1, 4, 4, 4, 3, 3, 4, 3, 2, 4, 2, 3, 3, 1, 3, 4, 1, 4, 4, 1, 2, 1, 3, 2, 1, 3, 4, 4, 3, 4, 3, 4, 3, 3, 1, 3, 4, 2, 1, 4, 2, 1, 1, 3, 2, 2, 2, 2, 1, 1, 4, 4, 1, 4, 4, 3, 4, 3, 1, 3, 2]
seq_wt_nucl = ''
seq_wt_dig_codons = []
seq_wt_nucl_codons = []
for i in range(len(seq_wt_dig)):
    seq_wt_nucl += dig2nucl[seq_wt_dig[i]]
    if i%3 == 0:
        seq_wt_dig_codons.append(seq_wt_dig[i:i+3])

StopCodons = ['TAA','TAG','TGA']
StopCodons_dig = [[4,1,1],[4,1,3],[4,3,1]]
nucl_sites = np.array([4, 7, 12, 12, 14, 15, 21, 21, 31, 44, 44, 58, 72, 76, 80, 80, 87, 87, 94, 97, 100, 103, 127, 133, 136, 156, 156, 169, 172, 175, 184, 210, 274, 293, 293, 295, 298, 310, 313, 334, 344, 344, 352, 365, 385, 404, 409, 416, 416, 436, 442, 446, 446, 448, 455, 456, 466, 482, 482, 491, 491, 497, 505, 509, 510, 527, 527, 535, 569, 570, 577]) - 1
sites = [x // 3 for x in nucl_sites]


c = 0
for site in sites:
    d = 100
    for SC in StopCodons_dig:
        diff = sum(x != y for x, y in zip(seq_wt_dig_codons[site], SC))
        if diff<d:
            d = diff
    if d == 1: c += 1
print(f"{c} out of {len(sites)} sites are at distance 1")

sites_at_dist1 = []
for (site,cod) in enumerate(seq_wt_dig_codons):
    d = 100
    for SC in StopCodons_dig:
        diff = sum(x != y for x, y in zip(cod, SC))
        if diff<d:
            d = diff
    if d == 1: sites_at_dist1.append(site)
    
missing = list(set(sites_at_dist1)-set(sites))
print(f"There are {len(missing)} sites that are at distance 1 from a stop codon and do not appear in the list given by Leo")
# Out:
# 71 out of 71 sites are at distance 1
# There are 0 sites that are at distance 1 from a stop codon and do not appear in the list given by Leo
