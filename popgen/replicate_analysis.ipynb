# %%
using DCAUtils, Statistics, StatsBase, PyPlot

Ns = [10^4,5*10^4,10^5, 5*10^5, 10^6]#, 5*10^6]

msas = [read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples10000_T12.0_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples50000_T12.0_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples100000_T12.02_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.0_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples1000000_T12.0_mu0.03_mubind-50.0_pairs10000.fa", 0.9)];
    
repl_msas = [read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples10000_T12.01_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples50000_T12.01_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples100000_T12.03_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.01_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/popgen/PSE_popgen_samples1000000_T12.01_mu0.03_mubind-50.0_pairs10000.fa", 0.9)];

mcmc_msas = [read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples10000_T1.3_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples50000_T1.3_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples100000_T1.3_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples500000_T1.3_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples1000000_T1.3_steps120_pairs10000.fa", 0.9)];

mcmc_repl_msas = [read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples10000_T1.31_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples50000_T1.31_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples100000_T1.31_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples500000_T1.31_steps120_pairs10000.fa", 0.9),
        read_fasta_alignment("../simulation_data/PSE/mcmc/PSE_mcmc_samples1000000_T1.31_steps120_pairs10000.fa", 0.9)];

q = 21
L, M = size(msas[1])
Lq = L*q
Lq2 = Lq*Lq


one_p = []
two_p = []
one_err = []
two_err = []

mcmc_one_p = []
mcmc_two_p = []
mcmc_one_err = []
mcmc_two_err = []



for i in 1:length(Ns)
    f1,f2 = compute_weighted_frequencies(msas[i], 22, 0.)
    repl_f1,repl_f2 = compute_weighted_frequencies(repl_msas[i], 22, 0.)
    push!(one_err, sum(abs2, f1[:] .- repl_f1[:]))
    push!(two_err, sum(abs2, f2[:] .- repl_f2[:]))
    push!(one_p, cor(f1[:], repl_f1[:]))
    push!(two_p, cor(f2[:], repl_f2[:]))

    #close("all");
    #plt.scatter(f2[:], repl_f2[:], label = "f2, cor = $(round(two_p[end], digits = 2))")
    #plt.scatter(f1[:], repl_f1[:], label = "f1, cor = $(round(one_p[end], digits = 2))")
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.title("PopGen, N = $(Ns[i])")
    #plt.legend()
    #savefig("popgen_replicate_freq_N$(Ns[i]).png")

    #close("all");
    #plt.hist((f2[:] .- repl_f2[:]) .^2, density = "true", linewidth = 3, histtype = "step", label = "f2, cor = $(round(two_p[end], digits = 2))")
    #plt.hist((f1[:] .- repl_f1[:]) .^2,  density = "true", linewidth = 3, histtype = "step", label = "f1, cor = $(round(one_p[end], digits = 2))")
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.xlabel("L2 error")
    #plt.title("PopGen, N = $(Ns[i])")
    #plt.legend()
    #savefig("popgen_hist_freq_N$(Ns[i]).png")
    
end



for i in 1:length(Ns)
    f1,f2 = compute_weighted_frequencies(mcmc_msas[i], 22, 0.)
    repl_f1,repl_f2 = compute_weighted_frequencies(mcmc_repl_msas[i], 22, 0.)
    push!(mcmc_one_err, sum(abs2, f1[:] .- repl_f1[:]))
    push!(mcmc_two_err, sum(abs2, f2[:] .- repl_f2[:]))
    push!(mcmc_one_p, cor(f1[:], repl_f1[:]))
    push!(mcmc_two_p, cor(f2[:], repl_f2[:]))

    #close("all");
    #plt.scatter(f2[:], repl_f2[:], label = "f2, cor = $(round(two_p[end], digits = 2))")
    #plt.scatter(f1[:], repl_f1[:], label = "f1, cor = $(round(one_p[end], digits = 2))")
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.title("MCMC, N = $(Ns[i])")
    #plt.legend()
    #savefig("mcmc_replicate_freq_N$(Ns[i]).png")
    
    #close("all");
    #plt.hist((f2[:] .- repl_f2[:]) .^2, density = "true", linewidth = 3, 
     #   histtype = "step", label = "f2, cor = $(round(two_p[end], digits = 2))")
    #plt.hist((f1[:] .- repl_f1[:]) .^2,  density = "true", linewidth = 3, 
     #   histtype = "step", label = "f1, cor = $(round(one_p[end], digits = 2))")
    #plt.xscale("log")
    #plt.yscale("log")
    #plt.xlabel("L2 error")
    #plt.title("MCMC, N = $(Ns[i])")
    #plt.legend()
    #savefig("mcmc_hist_freq_N$(Ns[i]).png")
    
end




q = 21
L, M = size(msas[1])
Lq = L*q
Lq2 = Lq*Lq

close("all");

plt.plot(1 ./ Ns, one_err/Lq, color = "darkgreen", label = "PopGen on f1")
plt.plot(1 ./ Ns, two_err/Lq2,  color = "lightgreen", label = "PopGen on f2")
plt.scatter(1 ./ Ns, one_err/Lq, color = "darkgreen")
plt.scatter(1 ./ Ns, two_err/Lq2, color = "lightgreen")

plt.plot(1 ./ Ns, mcmc_one_err/Lq, color = "darkred", label = "MCMC on f1")
plt.plot(1 ./ Ns, mcmc_two_err/Lq2,  color = "red", label = "MCMC on f2")
plt.scatter(1 ./ Ns, mcmc_one_err/Lq, color = "darkred")
plt.scatter(1 ./ Ns, mcmc_two_err/Lq2, color = "red")

plt.legend()
plt.xlabel("1/N", fontsize = 15)
plt.ylabel("L2 replicate error", fontsize = 15)
plt.xscale("log")
plt.yscale("log")
savefig("err_scaling.png")
    


close("all")

plt.plot(1 ./ Ns, one_p,  color = "darkgreen", label = "PopGen on f1")
plt.plot(1 ./ Ns, two_p,  color = "lightgreen",label = "PopGen on f2")
plt.scatter(1 ./ Ns, one_p,  color = "darkgreen")
plt.scatter(1 ./ Ns, two_p,  color = "lightgreen")

plt.plot(1 ./ Ns, mcmc_one_p,  color = "darkred", label = "MCMC on f1")
plt.plot(1 ./ Ns, mcmc_two_p,  color = "red",label = "MCMC on f2")
plt.scatter(1 ./ Ns, mcmc_one_p,  color = "darkred")
plt.scatter(1 ./ Ns, mcmc_two_p,  color = "red")

plt.legend()
plt.xlabel("1/N", fontsize = 15)
plt.ylabel("Pearson", fontsize = 15)
plt.xscale("log")
savefig("pearson_scaling.png")

# %%
single_msas = [read_fasta_alignment(
        "../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.01_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        "../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.02_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        "../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.03_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        "../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.04_mu0.03_mubind-50.0_pairs10000.fa", 0.9),
        "../simulation_data/PSE/popgen/PSE_popgen_samples500000_T12.05_mu0.03_mubind-50.0_pairs10000.fa", 0.9)];



SIZE = length(single_msas)

done_p = zeros(SIZE)
dtwo_p = zeros(SIZE)
done_err = zeros(SIZE)
dtwo_err = zeros(SIZE)

for i in 1:SIZE
    for j in i+1:SIZE 
        f1,f2 = compute_weighted_frequencies(single_msas[i], 22, 0.)
        repl_f1,repl_f2 = compute_weighted_frequencies(single_msas[j], 22, 0.)
        done_err[i,j] = sum(abs2, f1[:] .- repl_f1[:]))
        dtwo_err[i,j] = sum(abs2, f2[:] .- repl_f2[:]))
        done_p[i,j] = cor(f1[:], repl_f1[:]))
        dtwo_p[i,j] = cor(f2[:], repl_f2[:]))
    end
end
