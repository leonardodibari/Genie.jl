# %% [markdown]
# ## Testing Susceptibilities dynamical and background

# %%
using StatsBase

dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd.jld2"
 h = h_dbd; J = J_dbd;



N_steps = 3*10^6; N_chains = 500; N_start_seq = 200; NN_points = 500; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); res_all = [
    ]; hams_all = zeros(N_start_seq, N_points, N_chains); w = compute_weights(dbd_msa,
    22, 0.2)[1]; idx_seqs = sample(collect(1:size(dbd_msa,2)), ProbabilityWeights(w), 
    N_start_seq); start_seq = [dbd_msa[:, idx_seqs[i]] for i in 1:N_start_seq]; w_seqs = w[idx_seqs];

@time for n in 1:N_start_seq
    res = run_evolution(Int8.(hcat([start_seq[n] for i in 1:N_chains]...)), 
        h_dbd, 
        J_dbd, 
        p = 0.5, 
        temp = 1.0, 
        N_points = NN_points, 
        N_steps = N_steps);
    if n%10 == 0
        println("Initial seq $(n)")
    end
    push!(res_all, res) 
    hams_all[n,:,:] .= ham_dist(res.step_msa)
end


hams_single = zeros(N_start_seq, N_points); chi_dyn_single = zeros(N_start_seq, N_points);
for i in 1:N_start_seq
    for n in 1:N_points
        hams_single[i,n] = mean(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
        chi_dyn_single[i,n] = var(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
    end
end



close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(steps, chi_dyn_single[i,:], alpha = 0.05, color = "grey")
end

mean_chi_dyn_single = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];
plt.plot(steps, mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:], linewidth = 2.0, color = "black", label = "chi_dyn")

plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("chi_dyn_A")
plt.savefig("../single_wt_chi_dyn.png")


hams_single_all = mean(hams_all,dims = 3)[:,:,1]; mean_hams_single_all = mean(hams_single_all, Weights(w_seqs), dims = 1)[1,:];

close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(steps, hams_single_all[i,:], alpha = 0.2, color = "grey")
end

plt.plot(steps, mean_hams_single_all, linewidth = 2.0, color = "black", label = "<[H_A]>")


plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("[H_A]")
plt.savefig("../all_single_wt_mean_ham_dist.png")
    


hams0 = mean(hams_all,dims = 3)[:,:,1]; first_part = mean(hams0 .^2, Weights(w_seqs), dims = 1)[1,:];
second_part  = (mean(hams0, Weights(w_seqs), dims = 1)[1,:]) .^2; chi_back = first_part - second_part;

hams0_tot = mean(hams_all .^2 ,dims = 3)[:,:,1]; first_part_tot = mean(hams0_tot, Weights(w_seqs), dims = 1)[1,:];
chi_tot = first_part_tot - second_part; 

chi_dyn = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];

close("all")

plt.plot(res_all[1].steps, chi_dyn, color = "red", label = "chi_dyn")
plt.plot(res_all[1].steps, chi_back, color = "blue", label = "chi_back")
plt.plot(res_all[1].steps, chi_tot, color = "black", label = "chi_tot")

plt.legend()
plt.xscale("log")
plt.xlabel("MCMC steps")

savefig("../suscept_dbd_weight.png")

sum(abs2, chi_tot - chi_dyn - chi_back)
L = 76
sweeps = res_all[1].steps ./L ;

start_msa = hcat([res_all[i].step_msa[1][:,1] for i in 1:N_start_seq]...);

@save "../data_Genie/suscept_quantities_nucleotides.jld2" chi_dyn chi_back chi_tot start_msa sweeps N_chains N_points N_start_seq hams_single_all mean_hams_single_all w_seqs chi_dyn_single mean_chi_dyn_single


@save "../data_Genie/dbd_nucleo_evol.jld2" res_all

# %% [markdown]
# ## Testing Susceptibilities with Metropolis

# %%
using Revise, Genie, StatsBase, Statistics, JLD2, DCAUtils


res_all = [];

dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd.jld2"


N_steps = 3*10^6; N_chains = 500; N_start_seq = 200; NN_points = 500; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); hams_all = zeros(N_start_seq, N_points, N_chains); w = compute_weights(dbd_msa,
    22, 0.2)[1]; idx_seqs = sample(collect(1:size(dbd_msa,2)), ProbabilityWeights(w), 
    N_start_seq); start_seq = [dbd_msa[:, idx_seqs[i]] for i in 1:N_start_seq]; w_seqs = w[idx_seqs];



@time for n in 1:N_start_seq
    res = run_potts(Int8.(hcat([start_seq[n] for i in 1:N_chains]...)), 
        h_dbd, 
        J_dbd, 
        temp = 1.0, 
        N_points = NN_points, 
        N_steps = N_steps);
    if n%10 == 0
        println("Initial seq $(n)")
    end
    push!(res_all, res) 
    #hams_all[n,:,:] .= ham_dist(res.step_msa)
end

start_msa = hcat([res_all[i].step_msa[1][:,1] for i in 1:N_start_seq]...);

w_seqs = zeros(N_start_seq);
for n in 1:N_start_seq
    ds = ham_dist(start_msa[:,n], dbd_msa)
    w_seqs[n] = w[findfirst(ds .== 0)]
end  

for n in 1:N_start_seq
    hams_all[n,:,:] .= ham_dist(res_all[n].step_msa)
end
    
hams_single = zeros(N_start_seq, N_points); chi_dyn_single = zeros(N_start_seq, N_points);
for i in 1:N_start_seq
    for n in 1:N_points
        hams_single[i,n] = mean(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
        chi_dyn_single[i,n] = var(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
    end
end


close("all")
plt.plot()
for i in 1:5
    plt.plot(steps, hams_single[i,:],label = "seq $(idx_seqs[i])")
end


plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("[H_A]")
plt.savefig("../single_wt_mean_ham_dist.png")
        

close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(steps, chi_dyn_single[i,:], alpha = 0.05, color = "grey")
end

plt.plot(steps, mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:], linewidth = 2.0, color = "black", label = "chi_dyn")

plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("chi_dyn_A")
plt.savefig("../single_wt_chi_dyn.png")


hams_single_all = mean(hams_all,dims = 3)[:,:,1]; mean_hams_single_all = mean(hams_single_all, Weights(w_seqs), dims = 1)[1,:];

close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(steps, hams_single_all[i,:], alpha = 0.2, color = "grey")
end

plt.plot(steps, mean_hams_single_all, linewidth = 2.0, color = "black", label = "<[H_A]>")


plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("[H_A]")
plt.savefig("../all_single_wt_mean_ham_dist.png")
    


hams0 = mean(hams_all,dims = 3)[:,:,1]; first_part = mean(hams0 .^2, Weights(w_seqs), dims = 1)[1,:];
second_part  = (mean(hams0, Weights(w_seqs), dims = 1)[1,:]) .^2; chi_back = first_part - second_part;

hams0_tot = mean(hams_all .^2 ,dims = 3)[:,:,1]; first_part_tot = mean(hams0_tot, Weights(w_seqs), dims = 1)[1,:];
chi_tot = first_part_tot - second_part; 




chi_dyn = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];

close("all")

plt.plot(res_all[1].steps, chi_dyn, color = "red", label = "chi_dyn")
plt.plot(res_all[1].steps, chi_back, color = "blue", label = "chi_back")
plt.plot(res_all[1].steps, chi_tot, color = "black", label = "chi_tot")

plt.legend()
plt.xscale("log")
plt.xlabel("MCMC steps")

savefig("../suscept_dbd_weight.png")
sum(abs2, chi_tot - chi_dyn - chi_back)


###New part on AA, AB###

L = 76;
N_start_seq = 200; 
nn = 50

H_AB = zeros(N_start_seq, N_start_seq, N_points);
H_AB_sq = zeros(N_start_seq, N_start_seq, N_points);

for i in 1:nn#N_start_seq
    for j in i+1:nn#N_start_seq
        cc = ham_dist_AB_rp3(res_all[i].step_msa, res_all[j].step_msa, 200);
        H_AB[i,j,:] = cc[1]; H_AB[j,i,:] = cc[1];
        H_AB_sq[i,j,:] = cc[2]; H_AB_sq[j,i,:] = cc[2];
        #println((i,j))
    end
    println(i)
end

H_AB_mean = zeros(N_points);
H_AB_sq_mean = zeros(N_points);

for i in 1:nn
    for j in i+1:nn
        H_AB_mean .+= H_AB[i,j,:]
        H_AB_sq_mean .+= H_AB_sq[i,j,:]
    end
end
H_AB_mean ./= (nn*nn-nn)/2
H_AB_sq_mean ./= (nn*nn-nn)/2

axis_font = 15

sweeps = steps ./L
close("all")
plt.plot()
for i in 1:nn
    for j in i+1:nn
        plt.plot(sweeps, H_AB[i,j,:], alpha = 0.2, color = "grey")
    end
end
 

        
plt.plot(sweeps, H_AB_mean, linewidth = 2.0, color = "black", label = "\$ \\langle [ H_{AB} ] \\rangle \$")

plt.legend(fontsize = axis_font)
plt.xlabel("MC sweeps", fontsize = axis_font)
plt.xscale("log")
plt.ylabel("\$ [ H_{AB} ] \$", fontsize = axis_font)
plt.savefig("../all_pair_diff_wt_mean_ham_dist.png")




chi_AB_tot = H_AB_sq_mean .- (H_AB_mean.^2) 

tot_nn = Int(nn*(nn-1)/2)
H_AB_new = zeros(tot_nn, N_points)
H_AB_sq_new = zeros(tot_nn, N_points)
count = 1
for i in 1:nn
    for j in i+1:nn
        H_AB_new[count,:] = H_AB[i,j,:]
        H_AB_sq_new[count,:] = H_AB_sq[i,j,:]
        count+=1
    end
end

chi_AB_dyn = mean(H_AB_sq_new,dims = 1)[:] .- mean(H_AB_new.^2, dims = 1)[:]

chi_AB_back = mean(H_AB_new .^2 ,dims = 1)[:] .- (mean(H_AB_new, dims = 1)[:] .^2)


close("all")

plt.plot(sweeps, chi_AB_dyn, color = "red", label = "\$ \\chi_{dyn}^{AB} \$")
plt.plot(sweeps, chi_AB_back, color = "blue", label = "\$ \\chi_{back}^{AB} \$")
plt.plot(sweeps, chi_AB_tot, color = "black", label = "\$ \\chi_{tot}^{AB} \$")

plt.legend(fontsize = axis_font)
plt.xscale("log")
plt.xlabel("MC sweeps", fontsize = axis_font)

savefig("../suscept_AB_dbd_weight.png")
sum(abs2, chi_AB_tot - chi_AB_dyn - chi_AB_back)

### New part on AA####

sweeps = steps ./ 76

H_AA_new = zeros(N_start_seq, N_points);
H_AA_sq_new = zeros(N_start_seq, N_points);

for i in 1:N_start_seq
    cc = ham_dist_AB_rp3(res_all[i].step_msa, res_all[i].step_msa, 200);
    H_AA_new[i,:] .= cc[1]; 
    H_AA_sq_new[i,:] .= cc[2]; 
    println(i)
end

H_AA_sq_mean = mean(H_AA_sq_new, dims = 1)[:]; H_AA_mean = mean(H_AA_new, dims = 1)[:]; 

chi_AA_dyn = mean(H_AA_sq_new,dims = 1)[:] .- mean(H_AA_new.^2, dims = 1)[:]

chi_AA_back = mean(H_AA_new .^2 ,dims = 1)[:] .- (mean(H_AA_new, dims = 1)[:] .^2)

chi_AA_tot = H_AA_sq_mean .- (H_AA_mean.^2) 


close("all")

plt.plot(sweeps, chi_AA_dyn, color = "red", label = "\$ \\chi_{dyn}^{AA} \$")
plt.plot(sweeps, chi_AA_back, color = "blue", label = "\$ \\chi_{back}^{AA} \$")
plt.plot(sweeps, chi_AA_tot, color = "black", label = "\$ \\chi_{tot}^{AA} \$")

plt.legend(fontsize = axis_font)
plt.xscale("log")
plt.xlabel("MC sweeps", fontsize = axis_font)

savefig("../suscept_AA_dbd_weight.png")
sum(abs2, chi_AA_tot - chi_AA_dyn - chi_AA_back)


close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(sweeps, H_AA_new[i,:], alpha = 0.2, color = "grey")
end


plt.plot(sweeps, H_AA_mean, linewidth = 2.0, color = "black", label = "\$ \\langle [ H_{AA} ] \\rangle \$")

plt.legend(fontsize = axis_font)
plt.xlabel("MC sweeps", fontsize = axis_font)
plt.xscale("log")
plt.ylabel("\$ [ H_{AA} ] \$", fontsize = axis_font)
plt.savefig("../all_pair_wt_mean_ham_dist.png")


@save "../data_Genie/suscept_quantities_dbd_metropolis.jld2" start_msa H_AA_new H_AA_mean chi_AA_tot chi_AA_dyn chi_AA_back H_AB H_AB_mean chi_AB_tot chi_AB_dyn chi_AB_back chi_dyn_single chi_dyn chi_back chi_tot w_seqs N_start_seq N_chains L sweeps
# Out:
# Precompiling Genie
#   ✓ Genie
#   1 dependency successfully precompiled in 18 seconds. 143 already precompiled.
# SystemError: ../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m: No such file or directory
#
# Stacktrace:
#  [1] gzopen(fname::String, gzmode::String, gz_buf_size::Int64)
#    @ GZip ~/.julia/packages/GZip/vS3gf/src/gz.jl:193
#  [2] gzopen(fname::String, gzmode::String, gz_buf_size::Int64)
#    @ GZip ~/.julia/packages/GZip/vS3gf/src/gz.jl:206 [inlined]
#  [3] FastaReader
#    @ ~/.julia/packages/FastaIO/9VgiR/src/FastaIO.jl:44 [inlined]
#  [4] FastaIO.FastaReader(f::DCAUtils.ReadFastaAlignment.var"#1#2"{Float64}, filename::String, T::Type)
#    @ FastaIO ~/.julia/packages/FastaIO/9VgiR/src/FastaIO.jl:105
#  [5] FastaReader
#    @ FastaIO ~/.julia/packages/FastaIO/9VgiR/src/FastaIO.jl:105 [inlined]
#  [6] read_fasta_alignment(filename::String, max_gap_fraction::Float64)
# ...

# %% [markdown]
# ## Just on 3 sequences

# %%
using Revise, Genie, StatsBase, Statistics, JLD2, DCAUtils


res_all = [];

dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd.jld2"


N_steps = 3*10^6; N_chains = 500; N_start_seq = 3; NN_points = 500; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); hams_all = zeros(N_start_seq, N_points, N_chains); w = compute_weights(dbd_msa,
    22, 0.2)[1]; start_seq = [dbd_msa[:, i] for i in [17681, 13870, 19232]];



@time for n in 1:N_start_seq
    res = run_potts(Int8.(hcat([start_seq[n] for i in 1:N_chains]...)), 
        h_dbd, 
        J_dbd, 
        temp = 1.0, 
        N_points = NN_points, 
        N_steps = N_steps);
    if n%10 == 0
        println("Initial seq $(n)")
    end
    push!(res_all, res) 
    #hams_all[n,:,:] .= ham_dist(res.step_msa)
end

start_msa = hcat([res_all[i].step_msa[1][:,1] for i in 1:N_start_seq]...);

w_seqs = zeros(N_start_seq);
for n in 1:N_start_seq
    ds = ham_dist(start_msa[:,n], dbd_msa)
    w_seqs[n] = w[findfirst(ds .== 0)]
end  

for n in 1:N_start_seq
    hams_all[n,:,:] .= ham_dist(res_all[n].step_msa)
end
    
hams_single = zeros(N_start_seq, N_points); chi_dyn_single = zeros(N_start_seq, N_points);
for i in 1:N_start_seq
    for n in 1:N_points
        hams_single[i,n] = mean(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
        chi_dyn_single[i,n] = var(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
    end
end




hams_single_all = mean(hams_all,dims = 3)[:,:,1]; mean_hams_single_all = mean(hams_single_all, Weights(w_seqs), dims = 1)[1,:];

 


hams0 = mean(hams_all,dims = 3)[:,:,1]; first_part = mean(hams0 .^2, Weights(w_seqs), dims = 1)[1,:];
second_part  = (mean(hams0, Weights(w_seqs), dims = 1)[1,:]) .^2; chi_back = first_part - second_part;

hams0_tot = mean(hams_all .^2 ,dims = 3)[:,:,1]; first_part_tot = mean(hams0_tot, Weights(w_seqs), dims = 1)[1,:];
chi_tot = first_part_tot - second_part; 




chi_dyn = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];

sum(abs2, chi_tot - chi_dyn - chi_back)



dd1 = mean(hcat([ham_dist(res_all[1].step_msa[1][:,1],res_all[1].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

dd2 = mean(hcat([ham_dist(res_all[2].step_msa[1][:,1],res_all[2].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

dd3 = mean(hcat([ham_dist(res_all[3].step_msa[1][:,1],res_all[3].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

epis1, varr1, cons1, cde_wt1, entr1 = Genie.info_timescales(res_all[1].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

epis2, varr2, cons2, cde_wt2, entr2 = Genie.info_timescales(res_all[2].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

epis3, varr3, cons3, cde_wt3, entr3 = Genie.info_timescales(res_all[3].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

entr_v1 = mean(entr1[:,varr1], dims = 2)[:,1]; entr_epis1 = mean(entr1[:,epis1], dims = 2)[:,1];  entr_c1 = mean(entr1[:,cons1], dims = 2)[:,1];

entr_v2 = mean(entr2[:,varr2], dims = 2)[:,1]; entr_epis2 = mean(entr2[:,epis2], dims = 2)[:,1];  entr_c2 = mean(entr2[:,cons2], dims = 2)[:,1];

entr_v3 = mean(entr3[:,varr3], dims = 2)[:,1]; entr_epis3 = mean(entr3[:,epis3], dims = 2)[:,1];  entr_c3 = mean(entr3[:,cons3], dims = 2)[:,1];

@save "../data_Genie/3_seqs_sim.jld2" res_all start_msa hams_single_all mean_hams_single_all chi_dyn_single chi_dyn chi_back chi_tot epis3 varr3 cons3 cde_wt3 entr3 entr_v3 entr_epis3 entr_c3 epis2 varr2 cons2 cde_wt2 entr2 entr_v2 entr_epis2 entr_c2 epis1 varr1 cons1 cde_wt1 entr1 entr_v1 entr_epis1 entr_c1 dd1 dd2 dd3

# %% [markdown]
# ## Just on 3 sequences_but_with_profile

# %%
using Revise, Genie, StatsBase, Statistics, JLD2, DCAUtils


res_all = [];

dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd_profile.jld2"


N_steps = 3*10^6; N_chains = 500; N_start_seq = 3; NN_points = 500; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); hams_all = zeros(N_start_seq, N_points, N_chains); w = compute_weights(dbd_msa,
    22, 0.2)[1]; start_seq = [dbd_msa[:, i] for i in [17681, 13870, 19232]];



@time for n in 1:N_start_seq
    res = run_potts(Int8.(hcat([start_seq[n] for i in 1:N_chains]...)), 
        h_dbd, 
        J_dbd, 
        temp = 1.0, 
        N_points = NN_points, 
        N_steps = N_steps);
    if n%10 == 0
        println("Initial seq $(n)")
    end
    push!(res_all, res) 
    #hams_all[n,:,:] .= ham_dist(res.step_msa)
end

start_msa_p = hcat([res_all[i].step_msa[1][:,1] for i in 1:N_start_seq]...);

w_seqs = zeros(N_start_seq);
for n in 1:N_start_seq
    ds = ham_dist(start_msa_p[:,n], dbd_msa)
    w_seqs[n] = w[findfirst(ds .== 0)]
end  

for n in 1:N_start_seq
    hams_all[n,:,:] .= ham_dist(res_all[n].step_msa)
end
    
hams_single = zeros(N_start_seq, N_points); chi_dyn_single = zeros(N_start_seq, N_points);
for i in 1:N_start_seq
    for n in 1:N_points
        hams_single[i,n] = mean(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
        chi_dyn_single[i,n] = var(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
    end
end




hams_single_all = mean(hams_all,dims = 3)[:,:,1]; mean_hams_single_all = mean(hams_single_all, Weights(w_seqs), dims = 1)[1,:];

 


hams0 = mean(hams_all,dims = 3)[:,:,1]; first_part = mean(hams0 .^2, Weights(w_seqs), dims = 1)[1,:];
second_part  = (mean(hams0, Weights(w_seqs), dims = 1)[1,:]) .^2; chi_back = first_part - second_part;

hams0_tot = mean(hams_all .^2 ,dims = 3)[:,:,1]; first_part_tot = mean(hams0_tot, Weights(w_seqs), dims = 1)[1,:];
chi_tot = first_part_tot - second_part; 




chi_dyn = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];

sum(abs2, chi_tot - chi_dyn - chi_back)



dd1_p = mean(hcat([ham_dist(res_all[1].step_msa[1][:,1],res_all[1].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

dd2_p = mean(hcat([ham_dist(res_all[2].step_msa[1][:,1],res_all[2].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

dd3_p = mean(hcat([ham_dist(res_all[3].step_msa[1][:,1],res_all[3].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

epis1_p, varr1_p, cons1_p, cde_wt1_p, entr1_p = Genie.info_timescales(res_all[1].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

epis2_p, varr2_p, cons2_p, cde_wt2_p, entr2_p = Genie.info_timescales(res_all[2].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

epis3_p, varr3_p, cons3_p, cde_wt3_p, entr3_p = Genie.info_timescales(res_all[3].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

entr_v1_p = mean(entr1_p[:,varr1_p], dims = 2)[:,1]; entr_epis1_p = mean(entr1_p[:,epis1_p], dims = 2)[:,1];  entr_c1_p = mean(entr1_p[:,cons1_p], dims = 2)[:,1];

entr_v2_p = mean(entr2_p[:,varr2_p], dims = 2)[:,1]; entr_epis2_p = mean(entr2_p[:,epis2_p], dims = 2)[:,1];  entr_c2_p = mean(entr2_p[:,cons2_p], dims = 2)[:,1];

entr_v3_p = mean(entr3_p[:,varr3_p], dims = 2)[:,1]; entr_epis3_p = mean(entr3_p[:,epis3_p], dims = 2)[:,1];  entr_c3_p = mean(entr3_p[:,cons3_p], dims = 2)[:,1];

@save "../data_Genie/3_seqs_sim_profile.jld2" res_all start_msa_p hams_single_all mean_hams_single_all chi_dyn_single chi_dyn chi_back chi_tot epis3_p varr3_p cons3_p cde_wt3_p entr3_p entr_v3_p entr_epis3_p entr_c3_p epis2_p varr2_p cons2_p cde_wt2_p entr2_p entr_v2_p entr_epis2_p entr_c2_p epis1_p varr1_p cons1_p cde_wt1_p entr1_p entr_v1_p entr_epis1_p entr_c1_p dd1_p dd2_p dd3_p

# %% [markdown]
# ## Just on 3 sequences but with local profile of second sequence

# %%
using Revise, Genie, StatsBase, Statistics, JLD2, DCAUtils


res_all = [];

dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd_local_prof_seq13870.jld2"


N_steps = 3*10^6; N_chains = 500; N_start_seq = 3; NN_points = 500; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); hams_all = zeros(N_start_seq, N_points, N_chains); w = compute_weights(dbd_msa,
    22, 0.2)[1]; start_seq = [dbd_msa[:, i] for i in [17681, 13870, 19232]];



@time for n in 1:N_start_seq
    res = run_potts(Int8.(hcat([start_seq[n] for i in 1:N_chains]...)), 
        h_dbd, 
        J_dbd, 
        temp = 1.0, 
        N_points = NN_points, 
        N_steps = N_steps);
    if n%10 == 0
        println("Initial seq $(n)")
    end
    push!(res_all, res) 
    #hams_all[n,:,:] .= ham_dist(res.step_msa)
end

start_msa_lp = hcat([res_all[i].step_msa[1][:,1] for i in 1:N_start_seq]...);

w_seqs = zeros(N_start_seq);
for n in 1:N_start_seq
    ds = ham_dist(start_msa_p[:,n], dbd_msa)
    w_seqs[n] = w[findfirst(ds .== 0)]
end  

for n in 1:N_start_seq
    hams_all[n,:,:] .= ham_dist(res_all[n].step_msa)
end
    
hams_single = zeros(N_start_seq, N_points); chi_dyn_single = zeros(N_start_seq, N_points);
for i in 1:N_start_seq
    for n in 1:N_points
        hams_single[i,n] = mean(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
        chi_dyn_single[i,n] = var(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
    end
end




hams_single_all = mean(hams_all,dims = 3)[:,:,1]; mean_hams_single_all = mean(hams_single_all, Weights(w_seqs), dims = 1)[1,:];



hams0 = mean(hams_all,dims = 3)[:,:,1]; first_part = mean(hams0 .^2, Weights(w_seqs), dims = 1)[1,:];
second_part  = (mean(hams0, Weights(w_seqs), dims = 1)[1,:]) .^2; chi_back = first_part - second_part;

hams0_tot = mean(hams_all .^2 ,dims = 3)[:,:,1]; first_part_tot = mean(hams0_tot, Weights(w_seqs), dims = 1)[1,:];
chi_tot = first_part_tot - second_part; 


chi_dyn = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];

sum(abs2, chi_tot - chi_dyn - chi_back)


dd2_lp = mean(hcat([ham_dist(res_all[2].step_msa[1][:,1],res_all[2].step_msa[i][:,1:200]) for i in 1:415]...),dims = 1)[:];

epis2_lp, varr2_lp, cons2_lp, cde_wt2_lp, entr2_lp = Genie.info_timescales(res_all[2].step_msa, dbd_msa, h_dbd, J_dbd, res_all[1].steps);

entr_v2_lp = mean(entr2_lp[:,varr2_lp], dims = 2)[:,1]; entr_epis2_lp = mean(entr2_lp[:,epis2_lp], dims = 2)[:,1];  entr_c2_lp = mean(entr2_lp[:,cons2_lp], dims = 2)[:,1];


@save "../data_Genie/3_seqs_sim_local_profile.jld2" res_all start_msa_lp hams_single_all mean_hams_single_all chi_dyn_single chi_dyn chi_back chi_tot epis2_lp varr2_lp cons2_lp cde_wt2_lp entr2_lp entr_v2_lp entr_epis2_lp entr_c2_lp dd2_lp

# %% [markdown]
# ## Testing Sparse Model

# %%
using Revise, Genie, StatsBase, Statistics, JLD2, DCAUtils


res_all = [];

dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd_act.jld2"


N_steps = 3*10^6; N_chains = 500; N_start_seq = 200; NN_points = 500; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); hams_all = zeros(N_start_seq, N_points, N_chains); w = compute_weights(dbd_msa,
    22, 0.2)[1]; idx_seqs = sample(collect(1:size(dbd_msa,2)), ProbabilityWeights(w), 
    N_start_seq); start_seq = [dbd_msa[:, idx_seqs[i]] for i in 1:N_start_seq]; w_seqs = w[idx_seqs];



@time for n in 1:N_start_seq
    res = run_potts(Int8.(hcat([start_seq[n] for i in 1:N_chains]...)), 
        h_dbd, 
        J_dbd, 
        temp = 1.0, 
        N_points = NN_points, 
        N_steps = N_steps);
    if n%10 == 0
        println("Initial seq $(n)")
    end
    push!(res_all, res) 
    #hams_all[n,:,:] .= ham_dist(res.step_msa)
end

start_msa = hcat([res_all[i].step_msa[1][:,1] for i in 1:200]...);

w_seqs = zeros(N_start_seq);
for n in 1:N_start_seq
    ds = ham_dist(start_msa[:,n], dbd_msa)
    w_seqs[n] = w[findfirst(ds .== 0)]
end  

for n in 1:N_start_seq
    hams_all[n,:,:] .= ham_dist(res_all[n].step_msa)
end
    
hams_single = zeros(N_start_seq, N_points); chi_dyn_single = zeros(N_start_seq, N_points);
for i in 1:N_start_seq
    for n in 1:N_points
        hams_single[i,n] = mean(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
        chi_dyn_single[i,n] = var(ham_dist(res_all[i].step_msa[1], res_all[i].step_msa[n]))
    end
end


close("all")
plt.plot()
for i in 1:5
    plt.plot(steps, hams_single[i,:],label = "seq $(idx_seqs[i])")
end


plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("[H_A]")
plt.savefig("../single_wt_mean_ham_dist.png")
        

close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(steps, chi_dyn_single[i,:], alpha = 0.05, color = "grey")
end

plt.plot(steps, mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:], linewidth = 2.0, color = "black", label = "chi_dyn")

plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("chi_dyn_A")
plt.savefig("../single_wt_chi_dyn.png")


hams_single_all = mean(hams_all,dims = 3)[:,:,1]; mean_hams_single_all = mean(hams_single_all, Weights(w_seqs), dims = 1)[1,:];

close("all")
plt.plot()
for i in 1:N_start_seq
    plt.plot(steps, hams_single_all[i,:], alpha = 0.2, color = "grey")
end

plt.plot(steps, mean_hams_single_all, linewidth = 2.0, color = "black", label = "<[H_A]>")


plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("[H_A]")
plt.savefig("../all_single_wt_mean_ham_dist.png")
    


hams0 = mean(hams_all,dims = 3)[:,:,1]; first_part = mean(hams0 .^2, Weights(w_seqs), dims = 1)[1,:];
second_part  = (mean(hams0, Weights(w_seqs), dims = 1)[1,:]) .^2; chi_back = first_part - second_part;

hams0_tot = mean(hams_all .^2 ,dims = 3)[:,:,1]; first_part_tot = mean(hams0_tot, Weights(w_seqs), dims = 1)[1,:];
chi_tot = first_part_tot - second_part; 




chi_dyn = mean(chi_dyn_single, Weights(w_seqs), dims = 1)[1,:];

close("all")

plt.plot(res_all[1].steps, chi_dyn, color = "red", label = "chi_dyn")
plt.plot(res_all[1].steps, chi_back, color = "blue", label = "chi_back")
plt.plot(res_all[1].steps, chi_tot, color = "black", label = "chi_tot")

plt.legend()
plt.xscale("log")
plt.xlabel("MCMC steps")

savefig("../suscept_dbd_weight_sparse.png")
sum(abs2, chi_tot - chi_dyn - chi_back)

@save "../data_Genie/suscept_quantities_dbd__act_metropolis.jld2" start_msa chi_dyn_single chi_dyn chi_back chi_tot w_seqs N_start_seq N_chains L sweeps

# %% [markdown]
# ## Testing V

# %%
L, N_chains = size(res_all[1].step_msa[1]); N_steps = 415; N_wts = 200;

L = 76; N_chains = 500; N_steps = 415; N_wts = 200;
chi_dyn = zeros(N_wts, N_steps); qq = zeros(N_wts, N_steps, N_chains, L);
for w in 1:N_wts
    println(w)
    @time for t in 1:N_steps
        q = zeros(N_chains, L)
        for n in 1:N_chains 
            for i in 1:L
                q[n,i] = (v[res_all[w].step_msa[t][i,n],:]' * v[res_all[w].step_msa[1][i,n],:])/21                 
            end
        end
        qq[w,t,:,:] .= q
        chi_dyn[w,t] = sum(cov(q' * q))/L^2
    end 
end


ham = 1 .- mean(sum(qq, dims = 4) ./ (L/21), dims = 3)[:,:,1];


close("all")

for n in 1:N_wts
    plt.plot(steps[1:N_steps] ./L , chi_dyn[n,:], alpha = 0.2, color = "grey")
    plt.xscale("log")
end

plt.plot(steps[1:N_steps] ./L , mean(chi_dyn, dims = 1)[:], color = "black", 
    label = "\$ \\langle \\chi_{dyn}^{A}  \\rangle \$")

plt.xlabel("MCMC sweeps", fontsize = 15)
plt.ylabel("\$ \\chi_{dyn}^{A,v} \$", fontsize = 15)
plt.legend(fontsize = 15)
plt.savefig("../chi_dyn_miya_jern.png")



close("all")

for n in 1:N_wts
    plt.plot(steps[1:N_steps] ./L , ham[n,:], alpha = 0.2, color = "grey")
    plt.xscale("log")
end

plt.plot(steps[1:N_steps] ./L , mean(ham, dims = 1)[:], color = "black", 
    label = "\$ \\langle [ H^{v} ]  \\rangle \$")

plt.xlabel("MCMC sweeps", fontsize = 15)
plt.ylabel("\$ [ H^{v} ] \$", fontsize = 15)
plt.legend(fontsize = 15)
plt.savefig("../hamming_miya_jern.png")


@save "../data_Genie/suscept_dbd_miya_jern.jld2" ham chi_dyn qq

# %% [markdown]
# ## Viana-Bray

# %%
@load "../VB_diff_seq/big_save_simulations_VianaBray.jld2"

N_start_seq = length(res);
L,N_chains = size(res[1].step_msa[1]);
sweeps = res[1].times ./L ;
H = hcat([mean(ham_dist(res[i].step_msa), dims = 2) for i in 1:N_start_seq]...); 
H2 = [mean(ham_dist(res[i].step_msa).^2, dims = 2)[:,1] for i in 1:20];


chi_tot = mean(H2, dims = 2)[:,1] .- (mean(H, dims = 2)[:,1]).^2;
chi_back = mean(H .^2, dims = 2)[:,1] .- (mean(H, dims = 2)[:,1]).^2;
chi_dyn = mean(H2 .- (H.^2), dims = 2)[:,1];

sum(abs2, chi_tot .- chi_dyn .- chi_back)

@save "../data_Genie/VB_quantities.jld2"  sweeps chi_dyn chi_back chi_tot H H2 L

# %% [markdown]
# ## Guessing initial sequence

# %%
L = 76; N_steps = 415; all_wts = 200; N_wts = 10; corr = zeros(N_wts, all_wts, N_steps);

cdes = zeros(all_wts,L); cies = zeros(N_wts, N_steps, L);

@time for v in 1:all_wts
    cdes[v,:] .= cont_dep_entr(res_all[v].step_msa[1][:,1], h_dbd, J_dbd)
end

for w in 1:N_wts
    @time for t in 1:N_steps
        cies[w, t, :] = Genie.get_entropy(reshape(compute_weighted_frequencies(Int8.(res_all[w].step_msa[t]), 
                    22, 0.)[1], (21, L)))
    end
end

for w in 1:N_wts
    @time for t in 1:N_steps
        for v in 1:all_wts
            corr[w,v,t] = cor(cdes[v,:], cies[w,t,:])
        end
    end
end
    


idx = 8
close("all")
for v in 1:all_wts
    plt.plot(steps[1:N_steps] ./L , corr[idx,v,:], alpha = 0.2, color = "grey")
end

plt.plot(steps[1:N_steps] ./L , corr[idx,idx,:],  color = "black")
plt.xscale("log")
plt.xlabel("MCMC sweeps", fontsize = 15)
plt.ylabel("Pearson", fontsize = 15)       
plt.savefig("../trova_sequenza.png")


res = zeros(N_wts, N_steps);
color_vals = zeros(N_wts);

for w in 1:N_wts
    for t in 1:N_steps
        if argmax(corr[w,:,t]) == w
            res[w,t] = corr[w,w,t] - sort(corr[w,:,t], rev = true)[2]
        else
            res[w,t] = corr[w,w,t] - sort(corr[w,:,t], rev = true)[1]
        end
    end
end



close("all")

plt.plot(steps[1:N_steps] ./L, res', alpha = 0.2, color = "grey")
plt.plot(steps[1:N_steps] ./L, [0.0 for i in 1:N_steps], linestyle = "--", color = "black")

plt.xscale("log")
plt.xlabel("MCMC sweeps", fontsize = 15)
plt.ylabel("Indicator", fontsize = 15)

plt.savefig("../all_trova_sequenza.png")

# %%
using JLD2, PyPlot

@load "../../data_Genie/predicting_seqs_dbd.jld2"
# Out:
# 6-element Vector{Symbol}:
#  :corr
#  :res
#  :cdes
#  :cies
#  :start_msa
#  :steps

# %%
matrix = zeros(200,415)
 
for t in 1:415
    for w in 1:200
        for v in 1:200
            pred_wt = Int(argmax(corr[w,:,t]))
            matrix[w,t] = sum(start_msa[:,w] .!= start_msa[:,pred_wt])/76
        end
    end
end

# %%
plt.plot(steps ./ 76, [sum(matrix[:,t] .== 0.) for t in 1:415]./200, color = "black")
plt.plot(steps ./76, [1.0 for i in 1:415], color = "grey", linestyle = "--")
plt.ylabel("% of correct predictions", fontsize = 15)
plt.xlabel("MCMC sweeps", fontsize = 15)
plt.xscale("log")
plt.savefig("../../correct_predictions.png")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
## mean_pairwise is 0.6 with std of 0.06
z_score(x) = (0.6-x)/0.06
# Out:
# z_score (generic function with 1 method)

# %%
using Statistics

# %%
plt.plot(steps./76, [mean(z_score.(matrix[matrix[:,t] .!== 0., t])) for t in 1:415])
plt.plot(steps ./76, [0.0 for i in 1:415], color = "grey", linestyle = "--")
plt.ylabel("z_score of errors", fontsize = 15)
plt.xlabel("MCMC sweeps", fontsize = 15)
plt.xscale("log")
plt.savefig("../../z_score_predictin_dbd_errors.png")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.scatter(steps./76, matrix[200,:])
plt.xscale("log")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.scatter(inv_cde_seq, [steps[findfirst(matrix[w,3:end] .> 0.)] for w in 1:200])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f505d0345e0>

# %%
plt.scatter(steps./76, matrix[8,:])
plt.xscale("log")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
inv_cde_seq = 1 ./ sum(cdes, dims = 2)[:,1];

# %% [markdown]
# ## Testing Aging

# %%
dbd_msa  = read_fasta_alignment("../Gen.jl/data/alignments/natural/DBD_alignment.uniref90.cov80.a2m", 0.9);
@load "../data_Genie/pars_dbd.jld2"

#@load "../data_Genie/pars_dbd_act.jld2"

#h_dbd = h_dbd_act; J_dbd = J_dbd_act;

#@load "../data_Genie/pars_dbd_dec.jld2"

#h_dbd = h_dbd_dec; J_dbd = J_dbd_dec;


N_steps = 1*10^6; N_chains = 200; NN_points = 1000; steps = unique([
        trunc(Int,10^y) for y in range(log10(1), log10(N_steps), 
                length=NN_points)]); N_points = length(steps); res_all_T = [
    ]; idx_seqs = rand(1:size(dbd_msa,2), N_chains); Ts = [0.95, 1.0];

start_seqs = dbd_msa[:, idx_seqs];
@time res = run_evolution(Int8.(start_seqs), 
        h_dbd, 
        J_dbd, 
        p = 0.5, 
        temp = 1.0, 
        N_points = 5, 
        N_steps = 1*10^6);    
start_msa = res.step_msa[end];

@time for temp in Ts
    println(temp)
    @time res = run_evolution(Int8.(start_msa), 
        h_dbd, 
        J_dbd, 
        p = 0.5, 
        temp = temp, 
        N_points = NN_points, 
        N_steps = N_steps);    
    push!(res_all_T, res) 
end


hams_delayed1 = []; hams_delayed2 = []; hams_delayed3 = []; t_idxs = [95,262,428]; 
for i in 1:length(Ts)
    push!(hams_delayed1, [ham_dist(res_all_T[i].step_msa[t_idxs[1]], x) 
            for x in res_all_T[i].step_msa[t_idxs[1]:end]])
    push!(hams_delayed2, [ham_dist(res_all_T[i].step_msa[t_idxs[2]], x) 
            for x in res_all_T[i].step_msa[t_idxs[2]:end]])
    push!(hams_delayed3, [ham_dist(res_all_T[i].step_msa[t_idxs[3]], x) 
            for x in res_all_T[i].step_msa[t_idxs[3]:end]])
end


steps = res_all_T[1].steps;z_min = minimum(Ts); z_max = maximum(Ts);normalized_Ts = [
    (z - z_min) / (z_max - z_min) for z in Ts]; cmap = get_cmap("viridis"); cols = [cmap(z) for z in 
        normalized_Ts];


close("all")
plt.plot()
for i in 1:length(Ts)
    plt.plot(1 .+ steps[t_idxs[1]:end] .- steps[t_idxs[1]], [mean(x) for x in hams_delayed1[i]], color=cols[i], linewidth = 0.3, linestyle = ":",label = "T = $(round(Ts[i], digits = 2)) t_w = 10^2")
    plt.plot(1 .+ steps[t_idxs[2]:end] .- steps[t_idxs[2]], [mean(x) for x in hams_delayed2[i]], color=cols[i], linewidth = 1., linestyle = "--", label = "T = $(round(Ts[i], digits = 2)) t_w = 10^3")
    plt.plot(1 .+ steps[t_idxs[3]:end] .- steps[t_idxs[3]], [mean(x) for x in hams_delayed3[i]], color=cols[i], linewidth = 5., linestyle = "-.", label = "T = $(round(Ts[i], digits = 2)) t_w = 10^4")
end


plt.legend()
plt.xlabel("MCMC steps")
plt.xscale("log")
plt.ylabel("Mean Hamming Distance")
plt.savefig("../delayed_mean_ham_dist.png")

# %% [markdown]
# ## Testing G4 correlation

# %%
N_chains = 1000; N_steps = 10^6; start_seqs = dbd_msa[:, [22754,19,44,100,674]]; N_wts = size(start_seqs,2);
start_msas = [hcat([start_seqs[:,j] for i in 1:N_chains]...) for j in 1:N_wts]; 
w = compute_weights(dbd_msa,
    22, 0.2)[1]; idx_seqs = sample(collect(1:size(dbd_msa,2)), ProbabilityWeights(w), 
    N_chains); sub_msa = dbd_msa[:,idx_seqs];

res = [];

for i in 1:N_wts
    println(i)
    push!(res, run_evolution(Int8.(start_msas[i]), 
               h_dbd, 
               J_dbd, 
               p = 0.5, 
               N_points = 20, 
               N_steps = N_steps));
end

N_wts = 200
N_chains = 500
idx_seqs = sample(collect(1:size(dbd_msa,2)), ProbabilityWeights(w), 
    N_chains); sub_msa = dbd_msa[:,idx_seqs];
sub_msa = start_msa
start_seqs = start_msa
g4_nat = [G4(sub_msa, start_seqs[:,i], w_seqs) for i in 1:N_wts];
g4_sil = [G4(res_all[i].step_msa[end], start_seqs[:,i]) for i in 1:N_wts];
corr = [cor(g4_nat[i][:], g4_sil[i][:]) for i in 1:N_wts];


for i in 1:N_wts
    close("all")
    plt.scatter(g4_nat[i], g4_sil[i], label = "Cor: $(round(corr[i], digits = 3))")
    plt.title("Seq $(i)")
    plt.legend()
    plt.xlabel("G4_nat")
    plt.ylabel("G4_sil")
    savefig("../corr_seq$(i).png")
end


cdes = [cont_dep_entr(start_seqs[:,i], h_dbd, J_dbd) for i in 1:N_wts];
cie = CIE(dbd_msa);

epist = [std(abs.(cie-cdes[i])) for in 1:N_wts]
